# %% [markdown]
# <img height="42" src="../logos.png" width="320"/>
#
# **Avaliação com Utilizadores** -- Propostas de Solução

# %% [markdown]
# # Tarefa 4
#
# Dado o ECG anterior, já invertido:

# %%
from ltbio.biosignals.modalities import ECG
filepath_ = '../data/ecg.biosignal'
ecg = ECG.load(filepath_)
ecg.invert()

# %% [markdown]
# Existe um sinal de EMG no seguinte caminho:

# %%
filepath = '../data/emg.biosignal'

# %% [markdown]
# **Abrir EMG com o LTBio**
# Opção de Resolução 1:

# %%
from ltbio.biosignals.modalities import EMG
emg = EMG.load(filepath)

# %% [markdown]
# Opção de Resolução 2:

# %%
from ltbio.biosignals import Biosignal
emg = Biosignal.load(filepath)

# %% [markdown]
# Ver:

# %%
emg.preview.plot()

# %% [markdown]
# **Adcionar ruído miogénico ao ECG:**
# Opção de Resolução 1:

# %%
noisy_ecg = ECG.withAdditiveNoise(ecg, emg)

# %% [markdown]
# Opção de Resolução 2:

# %%
noisey_ecg = ecg + emg

# %% [markdown]
# **Confirmar ruído está ECG:**
# Opção de Resolução 1:

# %%
from ltbio.biosignals import plot_comparison
plot_comparison((ecg.preview, noisy_ecg.preview))
pass

# %% [markdown]
# Opção de Resolução 2:

# %%
ecg.preview.plot()
noisy_ecg.preview.plot()
pass

# %% [markdown]
# Opção de Resolução 3:

# %%
noisy_ecg.added_noise
# Out:
# Name: L-Bicep EMG with Gel Electrodes
# Type: EMG
# Location: Left Bicep
# Number of Channels: 1
# Channels: Left Bicep,
# Useful Duration: 0:37:20.400000
# Source: ScientISST Sense
# Events:
# - baseline: [07 Jul, 18:00:41; 07 Jul, 18:01:25]
# - lift: [07 Jul, 18:02:19; 07 Jul, 18:03:57]
# - greetings: [07 Jul, 18:04:24; 07 Jul, 18:04:56]
# - gesticulate: [07 Jul, 18:05:36; 07 Jul, 18:06:44]
# - walk_before: [07 Jul, 18:07:38; 07 Jul, 18:12:06]
# - run: [07 Jul, 18:15:02; 07 Jul, 18:47:33]
# - walk_after: [07 Jul, 18:47:33; 07 Jul, 18:51:00]

# %% [markdown]
# **Resposta às perguntas colocadas:**
# * Sim, confirmo que há ruído miogénico em algumas porções do sinal (ou equivalente).
