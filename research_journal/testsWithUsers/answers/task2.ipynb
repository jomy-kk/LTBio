# %% [markdown]
# <img height="42" src="../logos.png" width="320"/>
#
# **Avaliação com Utilizadores** -- Propostas de Solução

# %% [markdown]
# # Tarefa 2
#
# Dado o ECG anterior:

# %%
from ltbio.biosignals.modalities import ECG
filepath = '../data/ecg.biosignal'
ecg = ECG.load(filepath)

# %% [markdown]
# **Consultar eventos**
# Opção de Resolução 1:

# %%
ecg
# Out:
# Name: Chest-Abdomen ECG
# Type: ECG
# Location: Chest
# Number of Channels: 2
# Channels: Band, Gel,
# Useful Duration: 0:41:30
# Source: ScientISST Sense
# Events:
# - baseline: [07 Jul, 18:00:41; 07 Jul, 18:01:25]
# - lift: [07 Jul, 18:02:19; 07 Jul, 18:03:57]
# - greetings: [07 Jul, 18:04:24; 07 Jul, 18:04:56]
# - gesticulate: [07 Jul, 18:05:36; 07 Jul, 18:06:44]
# - walk_before: [07 Jul, 18:07:38; 07 Jul, 18:12:06]
# - run: [07 Jul, 18:15:02; 07 Jul, 18:47:33]
# - walk_after: [07 Jul, 18:47:33; 07 Jul, 18:51:00]

# %% [markdown]
# Opção de Resolução 2:

# %%
ecg.events
# Out:
# (baseline: [07 Jul, 18:00:41; 07 Jul, 18:01:25],
#  lift: [07 Jul, 18:02:19; 07 Jul, 18:03:57],
#  greetings: [07 Jul, 18:04:24; 07 Jul, 18:04:56],
#  gesticulate: [07 Jul, 18:05:36; 07 Jul, 18:06:44],
#  walk_before: [07 Jul, 18:07:38; 07 Jul, 18:12:06],
#  run: [07 Jul, 18:15:02; 07 Jul, 18:47:33],
#  walk_after: [07 Jul, 18:47:33; 07 Jul, 18:51:00])

# %% [markdown]
# **Gráfico na região do Evento**
# Opção de Resolução 1:

# %%
ecg['run'].preview.plot()
pass

# %% [markdown]
# Opção de Resolução 2:

# %%
run = ecg['run']
run.preview.plot()
pass

# %% [markdown]
# Opção de Resolução 3:

# %%
i = ecg.events[-2].onset
i
# Out:
# datetime.datetime(2022, 7, 7, 18, 15, 2, 780000)

# %%
f = ecg.events[-2].offset
f
# Out:
# datetime.datetime(2022, 7, 7, 18, 47, 33, 860000)

# %%
ecg[i: f].preview.plot()

# %% [markdown]
# **Resposta às perguntas colocadas:**
# * Sim, o ECG está invertido (ou equivalente).

# %% [markdown]
# **Inverter ECG**
# Opção de Resolução 1:

# %%
ecg.invert()
ecg['run'].preview.plot()
# ou
run.invert()
run.preview.plot()
pass

# %% [markdown]
# Opção de Resolução 2:

# %%
run *= -1
# ou baseline = baseline * -1
run.preview.plot()
pass

# %% [markdown]
# Opção de Resolução 3:

# %%
run = -run
run.preview.plot()
pass

# %% [markdown]
# **Resposta às perguntas colocadas:**
# * Sim, o ECG agora já está correto (ou equivalente).
